# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx

# %%
mpl_params = {
    "axes.titlesize": 20,
    "figure.figsize": (12, 4),
}

# %%
plt.rcParams.update(mpl_params)

# %%
G2 = nx.random_geometric_graph(10, 0.5)

# %%
nx.draw(G2, with_labels=True)

# %%
nx.shortest_path(G2,source=4,target=1)
# Out:
# [4, 8, 9, 1]
