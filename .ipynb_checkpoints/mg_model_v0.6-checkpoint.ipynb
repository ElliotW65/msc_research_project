# %%
import pickle
import mesa
import mesa.time
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
import networkx as nx

from scipy.stats import beta
from scipy.stats import weibull_min as wei
from scipy.special import gamma
import geopandas as gp
from mesa.space import NetworkGrid
from shapely.geometry import Point

import pyswarms as ps
from pyswarms.utils.functions import single_obj as fx

# %%
df = pickle.load(open("D:/Documents/MSc Project/data/aggregated_data.p", 'rb'))

# %%
solar_data = pickle.load(open("D:/Documents/MSc Project/data/solar_data.p", 'rb'))

# %%
wind_data = pickle.load(open("D:/Documents/MSc Project/data/wind_data.p", 'rb'))

# %%
G = nx.read_graphml("D:/Documents/MSc Project/data/edin_graph.graphml")

# %%
node_attr = pickle.load(open("D:/Documents/MSc Project/data/node_attributes.p", 'rb'))

# %%
nx.set_node_attributes(G, node_attr)

# %%
road_nodes = gp.read_file("D:/Documents/MSc Project/data/road_nodes.shp")

# %%
road_edges = gp.read_file("D:/Documents/MSc Project/data/road_edges.shp")

# %%
class RESAgent(mesa.Agent):
    
    'An agent for the renewable energy sources in the microgrid.'
    
    def __init__(self, pv_size, model):
        super().__init__(pv_size, model)
        self.stepper = 0
        self.month = self.model.month
        self.day = 0
        self.solar_data = None
        self.wind_data = None
        self.agent_name = "RES_Agent"
        self.panel_size = pv_size
        self.panel_efficiency = 0.26
        
        self.wt_rated_power = 1.5
        self.wt_rated_ws = 12.5
        self.wt_cut_in = 3.4
        self.wt_cut_out = 22
        
    def update_solar_and_wind_data(self):
        'Function to update the data in the time step'
        self.solar_data = self.model.solar_data[self.month][self.stepper]
        self.wind_data = self.model.wind_data[self.month][self.stepper]
        
    def get_solar_value(self):
        'Function to return the expected value from the beta distribution generated using historic data'

        cut = self.solar_data
        
        if not cut.sum() > 0:
            return 0

        norm_max = cut.max()
        norm_min= cut.min()

        'Normalise the data with min max normalisation'
        cut = (cut - norm_min) / (norm_max - norm_min)

        mean = cut.mean()
        sd = cut.std()

        a = (1-mean)*((mean*(1+mean)/(sd**2))-1)
        b = mean*a/1-mean

        result = beta.mean(a,b)

        'Reverse normalisation to get value in W/m2'
        result = result * (norm_max - norm_min) + norm_min

        return result
    
    def get_wind_value(self):
        'Function to return the expected value from the beta distribution generated using historic data'

        cut = self.wind_data

        sd = cut.std()

        mean = cut.mean()

        shape = (sd/mean)**-1.086

        scale = mean/gamma(1+1/shape)

        rs = wei.rvs(shape, scale=scale)

        return rs
    
    def get_wt_output(self, ws):
        'Function to calculate the output of the wind turbine given the input wind speed'
        
        power = 0
        
        if ws < self.wt_cut_in:
            return 0
        elif ws > self.wt_cut_in and ws < self.wt_rated_ws:
            return ((ws-self.wt_cut_in)/(self.wt_rated_ws - self.wt_cut_in))
        elif self.wt_rated_ws <= ws and ws <= self.wt_cut_out:
            return self.wt_rated_power
        elif ws > self.wt_cut_out:
            return 0
        else:
            return "Error"
    
        
    def step(self):
        self.update_solar_and_wind_data()
        irr = self.get_solar_value()
        wind_speed = self.get_wind_value()
        wt_gen = self.get_wt_output(wind_speed)
        pv_gen = (irr * self.panel_size * self.panel_efficiency)/1000
        self.model.schedule.agents[13].update_pv(pv_gen)
        self.model.schedule.agents[13].update_wt(wt_gen)
        self.stepper += 1

# %%
class BatteryAgent(mesa.Agent):
    
    'An agent to control the battery.'
    
    def __init__(self, model):
        super().__init__(self, model)
        self.stepper = 0
        self.agent_name = "Battery_Agent"
        
    def update_pv(self, new_pv):
        self.pv_output = new_pv
        
    def step(self):
        #print("PV Ouptut: ", self.pv_output)
        self.stepper += 1

# %%
class ResiLoadAgent(mesa.Agent):
    
    'An agent for the residential loads in the microgrid'
    
    def __init__(self, model, df):
        super().__init__(self, model)
        self.stepper = 0
        self.day = 0
        self.month = self.model.month
        self.agent_name = "Resi_Load_Agent"
        self.df = df
        self.houses = self.df.keys()
        self.total_load = 0
        #print("Houses: ", self.houses)
        
    def update_load_data(self):
        'Function to update the data in the dataframe to the latest days'
        for i in self.houses:
            self.df[i] = self.model.resi_df_format[i]
            
    def update_day(self):
        'Update to whether weekday or weekend data is being taken'
        self.day += 1 if self.day == 0 else -1
        self.month += 1 if self.day == 1 else 0
        
    def sum_load(self):
        'Function to calculate the total load for the current time period'
        #self.total_load += 1
        
        for i in self.houses:
            self.total_load += self.df[i].iloc[self.stepper].values[0]

    
    
    
    def step(self):
        self.total_load = 0
        self.update_load_data()
        self.sum_load()
        self.model.schedule.agents[13].update_resi_load(self.total_load)
        self.update_day()
        self.stepper += 1

# %%
class EVAgent(mesa.Agent):
    
    'An agent to control the electric vehicles'
    
    def __init__(self, model, activities, name):
        super().__init__(self, model)
        G = self.model.graph
        self.stepper = 0
        
        self.SOC = 20.0
        self.SOC_perc = 0
        self.get_soc_perc()
        self.charge = False
        self.location = '647313'
        self.distance_travelled = 0
        self.battery_soc = None
        self.activity_dict = activities
        self.activities = self.get_day()
        self.activity_counter = 0
        self.current_activity = "Home"
        self.move_check = False
        self.activity_timer = 0
        self.name = name
        self.leave_time = self.leave_time()
        print(self.name, ": Activities: ", self.activities)
        
    def random_exclude(self, n, end, start = 0):
        return list(range(1,n)) + list(range(n+1, end))
    
    def get_day(self):
        'Function to plan the day'
        time, activities = self.plan_day()
        
        while time > 10:
            time, activities = self.plan_day()
        
            
        return activities
    
    def plan_day(self):
        'Function to select the activites to be done that day'
        num_activities = len(self.activity_dict)
        probs = [0.08, 0.08,0.08,0.08, 0.3, 0.3, 0.08]
        n = np.random.choice(np.arange(3, 6))
        choices = np.random.choice(list(self.activity_dict.keys()), size=n, replace=False, p=probs)
        result = []
        time = 0
        for x in choices:
            result.append(x)
            time += self.activity_dict[x]['time']
        return time, result
    
    def find_node(self, activity):
        'Function to find nodes that match the activity'
        nodes = []
        act_type = self.activity_dict[activity]['node']
        for i in G.nodes():
            if G.nodes[i]['type'] == act_type:
                nodes.append(i)
        target = random.choice(nodes)
        return target
            
    def get_path(self, start, end):
        'Function to return the shortest path from the starting node to the end node specified'
        
        return nx.shortest_path(G,source=str(start),target=str(end))
    
    def get_distance(self, path):
        'Function to compute the distance of the path specified'
        
        distance = 0
        
        for i in range(len(path)-1):
            distance += float(G.edges[(path[i], path[i+1], 0)]['length']) * 0.000621371
            
        return distance
    
    def leave_time(self):
        'Function to decide a time to leave in the morning between 6 and 10 based on prob dist'
        
        return np.random.choice(np.arange(6, 10), p=[0.15, 0.35, 0.35, 0.15])
    
    def update_soc(self, distance):
        'Function to calculate the SOC of the battery after the most recent trip'
        
        p_used = distance * 0.24
        
        self.SOC = self.SOC - p_used + 1 * (0.2 * 0 - 1/0.2 * 0)
        
        if self.SOC <= 20:
            self.charge = True
            print(self.name, " Needs Charging")
            
    def V2G(self, v2g_charge):
        'Funciton to reduce the EVs SOC by the amount taken for V2G'
        self.SOC -= v2g_charge
        self.get_soc_perc()
            
    def get_soc_perc(self):
        'Function that updates the SOC as a percentage'
        
        self.SOC_perc = self.SOC / 75 *100
            
    def charging_check(self):
        'Function to determine whether the EV is chargin or not'
        
#         if self.SOC_perc < 80 and self.current_activity == "Home" or self.SOC_perc < 80 and self.current_activity == "Work" :
#             self.charge = True
        if self.current_activity == "Home" or self.current_activity == "Work1" or self.current_activity == "Work2" :
            self.charge = True
        else:
            self.charge = False
            
    def charge_EV(self):
        'Function to charge the EV'
        
        self.SOC += 7.104
        self.get_soc_perc()
        
    
    
    def move(self, destination_node):
        self.location = destination_node
        self.model.graph.move_agent(self, self.location)
        
        
    def step(self):
        
        self.charging_check()
        
        if self.leave_time == self.stepper:
            self.move_check = True
            
        if self.charge:
            print(self.name, " Charging... ", self.SOC_perc, ", Location: ", self.current_activity)
            self.model.schedule.agents[12].update_demand(7.104, self.SOC)
            self.charge_EV()
            print(self.name, " Charging at end of hour ", self.SOC_perc)
        
        if self.move_check:
            self.move_check = False
            if self.activity_counter >= len(self.activities):
                next_activity = "Home"
            else:
                next_activity = self.activities[self.activity_counter]

            destination = self.find_node(next_activity)
            path = self.get_path(self.location, destination)
            #print(self.name ,": Path: ", path)
            distance = self.get_distance(path)
            #print(self.name, ": Distance: ", distance)
            self.distance_travelled += distance
            self.update_soc(distance)
            self.get_soc_perc()
            
            self.move(destination)
            
            self.current_activity = next_activity
            self.activity_timer = self.activity_dict[self.current_activity]['time'] + 1
            
            self.activity_counter += 1


            #self.distance_travelled += distance
            'Work out battery SOC'
            
        self.activity_timer -= 1
        
        if self.activity_timer == 0 and self.activity_counter <= len(self.activities):
            self.move_check = True
            
        self.stepper += 1

# %%
class EVAggregatorAgent(mesa.Agent):
    
    'Agent to aggregate data from the EVs'
    
    def __init__(self, model):
        super().__init__(self, model)
        self.stepper = 0
        self.agent_name = "EV_Aggregator_Agent"
        self.EV_demand = []
        self.EV_SOC = []
        
    def update_demand(self, demand, soc):
        'Function to update the total EV demand, called by EV agents'
        
        self.EV_demand.append(demand)
        self.EV_SOC.append(soc)
        
    def step(self):
        self.model.schedule.agents[13].update_EV_load(self.EV_demand, self.EV_SOC)
        self.EV_demand = []
        self.EV_SOC = []

# %%
class ControlAgent(mesa.Agent):
    
    'An agent to control the microgrid.'
    
    def __init__(self, model):
        super().__init__(self, model)
        self.stepper = 0
        self.agent_name = "Control_Agent"
        self.pv_output = 0
        self.wt_output = 0
        self.total_resi_load = 0
        self.EV_loads = []
        self.EV_SOCs = []
        self.total_EV_load = 0
        self.total_demand = 0
        self.total_gen = 0
        self.resi = []
        self.ev = []
        
    def update_pv(self, new_pv):
        self.pv_output = new_pv
        
    def update_wt(self, new_wt):
        self.wt_output = new_wt
        
    def update_resi_load(self, load):
        self.total_resi_load = load
        
    def update_EV_load(self, load, soc):
        self.EV_loads = load
        self.EV_SOCs = soc
        
    def obj_function(x, demand, charges):
        'Objective function of charging PSO algorithm'
        perc = x/charges*100
        value = abs(demand-np.sum(x,axis=1)) + np.var(perc, axis=1)
        return value
    
    def PSO_optimisation(self, deficit):
        'Function to run the PSO charging algorithm'
        
        num_EVs = len(self.EV_loads)
        
        params = {'c1': 0.3, 'c2': 0.5, 'w':0.7}
        bounds = (np.full(num_EVs,0), np.full(num_EVs,7))
        optimizer = ps.single.GlobalBestPSO(n_particles=50, dimensions=num_EVs, options=options, bounds=bounds)
        cost, pos = optimizer.optimize(obj_function, iters=100, demand=deficit, charges=np.array(self.EV_SOCs), verbose=False)
        
        return pos
        
    def step(self):
        self.total_EV_load = sum(self.EV_loads)
        self.total_demand = self.total_resi_load + self.total_EV_load
        self.total_gen = self.pv_output + self.wt_output
        
        deficit = self.total_demand - self.total_gen
        
        print("\nTotal Generation: ", self.total_gen)
        print("Total Demand: ", self.total_demand)
        
        print("Initial deficit: ", deficit)
        
        if deficit > 0 :
            updated_demand = self.total_demand - self.total_EV_load
            deficit = updated_demand - self.total_gen
            print("Demand w/ no EVs: ", updated_demand)
            print("New deficit: ", deficit)
            if deficit > 0 and len(self.EV_loads) > 0:
                print("Running PSO...")
                V2G_charges = self.PSO_optimisation(deficit)
                print("Output: ", V2G_charges)
                updated_gen = self.total_gen + V2G_charges.sum()
                print("Updated Gen: ", updated_gen)
                updated_demand = updated_demand - updated_gen
                print("Updated Demand: ", updated_demand)
                
        
        for i in range(len(V2G_charges)):
            self.model.schedule.agents[i+2].V2G(V2G_charges[i])
                
        
#         print("\nTotal Generation: ", self.total_gen)
#         print("Total Demand: ", self.total_demand)
        self.resi.append(self.total_resi_load)
        self.ev.append(self.total_EV_load)
        
        self.EV_loads = []
        self.EV_SOC = []
#         if self.stepper == 23:
#             print("Load: ", self.resi)
#             print("EV: ", self.ev)
        
        self.stepper += 1

# %%
class MicrogridModel(mesa.Model):
    
    'A model to simulate a microgrid.'
    
    def __init__(self, pv_size, irr, ws, df, graph, activities):
        self.month = 0
        self.panel_size = pv_size
        self.solar_data = irr
        self.wind_data = ws
        self.resi_df = df
        self.resi_df_format = {}
        self.houses = self.resi_df.keys()
        self.graph = NetworkGrid(graph)
        self.activities= activities
        
        self.schedule = mesa.time.BaseScheduler(self)
        
        self.day = 0
        self.month = 0
        
        self.update_load_data()
        
        #Create agents
        
        #print(type(self.graph))
        
        res = RESAgent(self.panel_size, self)
        residential = ResiLoadAgent(self, self.resi_df_format)
        evs = [EVAgent(self, activities, "EV"+str(i)) for i in range(10)]
#         ev1 = EVAgent(self, activities, "EV1")
#         ev2 = EVAgent(self, activities, "EV2")
#         ev3= EVAgent(self, activities, "EV3")
        ev_agg = EVAggregatorAgent(self)
        ctrl = ControlAgent(self)

        self.schedule.add(res)
        self.schedule.add(residential)
        for i in evs:
            self.schedule.add(i)
            self.graph.place_agent(i, '647313')
#         self.schedule.add(ev1)
#         self.schedule.add(ev2)
#         self.schedule.add(ev3)
        self.schedule.add(ev_agg)
        self.schedule.add(ctrl)
        
        print("Agents: ",len(self.schedule.agents))
        
        
    def update_date(self):
        'Update to whether weekday or weekend data is being taken'
        self.month += 1 if self.day == 1 else 0
        self.day += 1 if self.day == 0 else -1
        
    def update_load_data(self):
        'Function to update the data in the dataframe to the latest days'
        for i in self.houses:
            self.resi_df_format[i] = self.resi_df[i][self.month][self.day]
        
        
    def step(self):
        'Move the model forward by one time step'
        self.update_load_data()
        #print("Data: ", self.resi_df_format)
        for i in range(24):
            print("\nHour: ", i)
            self.schedule.step()

# %%
activities = {"Home": {"node": "home", "time" : 0},
             "Shopping": {"node": "leisure", "time" : 2},
             "Other": {"node": "other", "time" : 1},
             "Sport": {"node": "leisure", "time" : 2},
             "Work1": {"node": "work", "time" : 4},
             "Work2": {"node": "work", "time" : 4},
             "Food": {"node": "leisure", "time" : 1}}

# %%
probs = [0.1, 0.1,0.1,0.1, 0.25, 0.25, 0.1]

# %%
empty_model = MicrogridModel(40, solar_data, wind_data, df, G, activities)
empty_model.step()
# Out:
# EV0 : Activities:  ['Shopping', 'Work2', 'Work1']
# EV1 : Activities:  ['Work2', 'Food', 'Home', 'Other', 'Work1']
# EV2 : Activities:  ['Work2', 'Other', 'Work1', 'Home']
# EV3 : Activities:  ['Work2', 'Food', 'Work1', 'Other']
# EV4 : Activities:  ['Shopping', 'Work1', 'Work2']
# EV5 : Activities:  ['Food', 'Other', 'Home']
# EV6 : Activities:  ['Other', 'Work1', 'Work2', 'Food']
# EV7 : Activities:  ['Work2', 'Shopping', 'Other']
# EV8 : Activities:  ['Food', 'Work2', 'Shopping']
# EV9 : Activities:  ['Work1', 'Sport', 'Work2']
# Agents:  14
#
# Hour:  0
# EV0  Charging...  26.666666666666668 , Location:  Home
# EV0  Charging at end of hour  36.138666666666666
# EV1  Charging...  26.666666666666668 , Location:  Home
# EV1  Charging at end of hour  36.138666666666666
# EV2  Charging...  26.666666666666668 , Location:  Home
# EV2  Charging at end of hour  36.138666666666666
# EV3  Charging...  26.666666666666668 , Location:  Home
# EV3  Charging at end of hour  36.138666666666666
# EV4  Charging...  26.666666666666668 , Location:  Home
# EV4  Charging at end of hour  36.138666666666666
# EV5  Charging...  26.666666666666668 , Location:  Home
# EV5  Charging at end of hour  36.138666666666666
# EV6  Charging...  26.666666666666668 , Location:  Home
# EV6  Charging at end of hour  36.138666666666666
# EV7  Charging...  26.666666666666668 , Location:  Home
# EV7  Charging at end of hour  36.138666666666666
# EV8  Charging...  26.666666666666668 , Location:  Home
# EV8  Charging at end of hour  36.138666666666666
# EV9  Charging...  26.666666666666668 , Location:  Home
# EV9  Charging at end of hour  36.138666666666666
#
# Total Generation:  0.06971033767128754
# Total Demand:  84.20489377902094
# Initial deficit:  84.13518344134965
# Demand w/ no EVs:  13.164893779020929
# New deficit:  13.095183441349642
# Running PSO...
# Output:  [2.45220449 2.46502621 2.34160449 2.56131709 2.47384317 2.58964193
#  2.28509039 2.40120818 2.5552389  2.38947045]
# Updated Gen:  24.584355636513074
# Updated Demand:  -11.419461857492145
#
# Hour:  1
# EV0  Charging...  32.86906067639842 , Location:  Home
# EV0  Charging at end of hour  42.34106067639842
# EV1  Charging...  32.85196505248298 , Location:  Home
# EV1  Charging at end of hour  42.323965052482976
# EV2  Charging...  33.01652734880848 , Location:  Home
# EV2  Charging at end of hour  42.488527348808475
# EV3  Charging...  32.72357721996787 , Location:  Home
# EV3  Charging at end of hour  42.195577219967866
# EV4  Charging...  32.840209102427536 , Location:  Home
# EV4  Charging at end of hour  42.31220910242753
# EV5  Charging...  32.68581076064628 , Location:  Home
# EV5  Charging at end of hour  42.15781076064628
# EV6  Charging...  33.091879485066045 , Location:  Home
# EV6  Charging at end of hour  42.56387948506604
# EV7  Charging...  32.93705575418329 , Location:  Home
# EV7  Charging at end of hour  42.40905575418329
# EV8  Charging...  32.73168147163585 , Location:  Home
# EV8  Charging at end of hour  42.20368147163585
# EV9  Charging...  32.95270606326087 , Location:  Home
# EV9  Charging at end of hour  42.42470606326087
#
# Total Generation:  0.0
# Total Demand:  81.8238052141698
# Initial deficit:  81.8238052141698
# Demand w/ no EVs:  10.783805214169789
# New deficit:  10.783805214169789
# Running PSO...
# Output:  [1.06410646 1.12507018 1.06053567 1.02261501 1.10446969 1.0620378
#  1.09391343 1.10130372 1.02397241 1.12576298]
# Updated Gen:  10.783787365136828
# Updated Demand:  1.7849032960981503e-05
#
# Hour:  2
# EV0  Charging...  40.9222520628564 , Location:  Home
# EV0  Charging at end of hour  50.3942520628564
# EV1  Charging...  40.82387147670132 , Location:  Home
# EV1  Charging at end of hour  50.29587147670133
# EV2  Charging...  41.07447979463404 , Location:  Home
# EV2  Charging at end of hour  50.546479794634045
# EV3  Charging...  40.832090537964675 , Location:  Home
# EV3  Charging at end of hour  50.304090537964676
# EV4  Charging...  40.839582844927655 , Location:  Home
# EV4  Charging at end of hour  50.31158284492766
# EV5  Charging...  40.74176035852307 , Location:  Home
# EV5  Charging at end of hour  50.21376035852306
# EV6  Charging...  41.10532823941864 , Location:  Home
# EV6  Charging at end of hour  50.57732823941864
# EV7  Charging...  40.94065078820333 , Location:  Home
# EV7  Charging at end of hour  50.41265078820333
# EV8  Charging...  40.83838492450507 , Location:  Home
# EV8  Charging at end of hour  50.31038492450508
# EV9  Charging...  40.92368875362763 , Location:  Home
# EV9  Charging at end of hour  50.39568875362763
#
# Total Generation:  0.0
# Total Demand:  81.18304078807812
# Initial deficit:  81.18304078807812
# Demand w/ no EVs:  10.14304078807811
# New deficit:  10.14304078807811
# Running PSO...
# Output:  [1.4820506  0.69079037 0.83236451 1.32909172 0.70883409 1.23071028
#  0.98323273 1.02683062 0.98568314 0.87110197]
# Updated Gen:  10.140690028375651
# Updated Demand:  0.0023507597024590154
#
# Hour:  3
# EV0  Charging...  48.418184602711875 , Location:  Home
# EV0  Charging at end of hour  57.89018460271187
# EV1  Charging...  49.37481764667949 , Location:  Home
# EV1  Charging at end of hour  58.8468176466795
# EV2  Charging...  49.43666045421031 , Location:  Home
# EV2  Charging at end of hour  58.90866045421031
# EV3  Charging...  48.53196824566394 , Location:  Home
# EV3  Charging at end of hour  58.00396824566394
# EV4  Charging...  49.3664707291083 , Location:  Home
# EV4  Charging at end of hour  58.838470729108295
# EV5  Charging...  48.57281331836583 , Location:  Home
# EV5  Charging at end of hour  58.044813318365826
# EV6  Charging...  49.26635126263306 , Location:  Home
# EV6  Charging at end of hour  58.73835126263306
# EV7  Charging...  49.043543294459965 , Location:  Home
# EV7  Charging at end of hour  58.51554329445996
# EV8  Charging...  48.99614073386475 , Location:  Home
# EV8  Charging at end of hour  58.46814073386475
# EV9  Charging...  49.23421945583011 , Location:  Home
# EV9  Charging at end of hour  58.70621945583011
#
# Total Generation:  0.6555473879550682
# Total Demand:  80.87746257711623
# Initial deficit:  80.22191518916117
# Demand w/ no EVs:  9.837462577116227
# New deficit:  9.18191518916116
# Running PSO...
# Output:  [2.39533161 0.44136466 1.33817575 1.54115178 0.6540464  0.50067589
#  0.90969103 0.42176663 0.6341622  0.34579187]
# Updated Gen:  9.837705204118725
# Updated Demand:  -0.00024262700249799707
#
# Hour:  4
# EV0  Charging...  54.69640912077113 , Location:  Home
# EV0  Charging at end of hour  64.16840912077113
# EV1  Charging...  58.25833143570994 , Location:  Home
# EV1  Charging at end of hour  67.73033143570993
# EV2  Charging...  57.12442612254307 , Location:  Home
# EV2  Charging at end of hour  66.59642612254308
# EV3  Charging...  55.94909920446054 , Location:  Home
# EV3  Charging at end of hour  65.42109920446055
# EV4  Charging...  57.96640885734933 , Location:  Home
# EV4  Charging at end of hour  67.43840885734933
# EV5  Charging...  57.37724546692559 , Location:  Home
# EV5  Charging at end of hour  66.8492454669256
# EV6  Charging...  57.52542988475905 , Location:  Home
# EV6  Charging at end of hour  66.99742988475906
# EV7  Charging...  57.953187791051974 , Location:  Home
# EV7  Charging at end of hour  67.42518779105198
# EV8  Charging...  57.622591136038814 , Location:  Home
# EV8  Charging at end of hour  67.09459113603882
# EV9  Charging...  58.24516363569996 , Location:  Home
# EV9  Charging at end of hour  67.71716363569996
#
# Total Generation:  0.21675992408712072
# Total Demand:  80.81838491162489
# Initial deficit:  80.60162498753778
# Demand w/ no EVs:  9.778384911624883
# New deficit:  9.561624987537762
# Running PSO...
# Output:  [0.98826317 1.02273091 0.99884982 1.29889369 0.69736133 0.54749294
#  1.09474028 1.19529821 0.73471682 0.95568436]
# Updated Gen:  9.750791466052341
# Updated Demand:  0.027593445572541953
#
# Hour:  5
# EV0  Charging...  62.85072489260949 , Location:  Home
# EV0  Charging at end of hour  72.32272489260949
# EV1  Charging...  66.36669021913461 , Location:  Home
# EV1  Charging at end of hour  75.83869021913462
# EV2  Charging...  65.26462635709798 , Location:  Home
# EV2  Charging at end of hour  74.73662635709798
# EV3  Charging...  63.68924094981067 , Location:  Home
# EV3  Charging at end of hour  73.16124094981066
# EV4  Charging...  66.50859374974262 , Location:  Home
# EV4  Charging at end of hour  75.98059374974262
# EV5  Charging...  66.11925488078322 , Location:  Home
# EV5  Charging at end of hour  75.59125488078323
# EV6  Charging...  65.53777617624988 , Location:  Home
# EV6  Charging at end of hour  75.00977617624987
# EV7  Charging...  65.83145684960996 , Location:  Home
# EV7  Charging at end of hour  75.30345684960996
# EV8  Charging...  66.11496870640377 , Location:  Home
# EV8  Charging at end of hour  75.58696870640378
# EV9  Charging...  66.44291781791355 , Location:  Home
# EV9  Charging at end of hour  75.91491781791355
#
# Total Generation:  0.011423659756201762
# Total Demand:  82.18028582098871
# Initial deficit:  82.16886216123251
# Demand w/ no EVs:  11.140285820988709
# New deficit:  11.128862161232506
# Running PSO...
# Output:  [0.72275933 1.6928216  0.62757455 1.06422551 0.57390816 0.48820347
#  2.21092203 1.29368635 0.56370416 1.89852762]
# Updated Gen:  11.147756452370341
# Updated Demand:  -0.007470631381632842
#
# Hour:  6
# EV0  Charging...  71.35904578069618 , Location:  Home
# EV0  Charging at end of hour  80.83104578069619
# EV1  Charging...  73.58159475472446 , Location:  Home
# EV1  Charging at end of hour  83.05359475472447
# EV2  Charging...  73.89986028510802 , Location:  Home
# EV2  Charging at end of hour  83.37186028510803
# EV3  Charging...  71.74227359793184 , Location:  Home
# EV3  Charging at end of hour  81.21427359793184
# EV4  Charging...  75.21538286681917 , Location:  Home
# EV4  Charging at end of hour  84.68738286681918
# EV5  Charging...  74.94031691980764 , Location:  Home
# EV5  Charging at end of hour  84.41231691980765
# EV6  Charging...  72.0618801333018 , Location:  Home
# EV6  Charging at end of hour  81.5338801333018
# EV7  Charging...  73.5785417191897 , Location:  Home
# EV7  Charging at end of hour  83.05054171918971
# EV8  Charging...  74.83536316441663 , Location:  Home
# EV8  Charging at end of hour  84.30736316441664
# EV9  Charging...  73.38354765387474 , Location:  Home
# EV9  Charging at end of hour  82.85554765387474
#
# Total Generation:  0.4405604206808161
# Total Demand:  87.53583361123975
# Initial deficit:  87.09527319055894
# Demand w/ no EVs:  16.495833611239746
# New deficit:  16.05527319055893
# Running PSO...
# Output:  [2.68214038 1.22005223 1.25419159 0.89008126 1.6585903  1.5133256
#  2.04631932 0.49655906 1.33786453 2.95960372]
# Updated Gen:  16.499288420757562
# Updated Demand:  -0.00345480951781596
#
# Hour:  7
# EV0  Charging...  77.25485860553528 , Location:  Home
# EV0  Charging at end of hour  86.7268586055353
# EV1  Charging...  81.42685844959372 , Location:  Home
# EV1  Charging at end of hour  90.89885844959372
# EV2  Charging...  81.6996048337063 , Location:  Home
# EV2  Charging at end of hour  91.17160483370633
# EV3  Charging...  80.02749857962715 , Location:  Home
# EV3  Charging at end of hour  89.49949857962714
# EV4  Charging...  82.47592913268065 , Location:  Home
# EV4  Charging at end of hour  91.94792913268066
# EV5  Charging...  82.39454945301692 , Location:  Home
# EV5  Charging at end of hour  91.86654945301692
# EV6  Charging...  78.8054543711103 , Location:  Home
# EV6  Charging at end of hour  88.27745437111028
# EV7  Charging...  82.3884629736586 , Location:  Home
# EV7  Charging at end of hour  91.86046297365861
# EV8  Charging...  82.5235437855744 , Location:  Home
# EV8  Charging at end of hour  91.99554378557441
# EV9  Charging...  76.79293900341091 , Location:  Work1
# EV9  Charging at end of hour  86.26493900341092
#
# Total Generation:  0.4247961962334417
# Total Demand:  102.02065868305863
# Initial deficit:  101.59586248682518
# Demand w/ no EVs:  30.98065868305862
# New deficit:  30.55586248682518
# Running PSO...
# Output:  [3.02041082 3.25414549 2.87417007 3.04950339 2.92658077 3.05916644
#  2.924102   3.32944597 3.3978084  2.72056893]
# Updated Gen:  30.980698483497907
# Updated Demand:  -3.980043928564214e-05
#
# Hour:  8
# EV0  Charging...  82.69964418303832 , Location:  Home
# EV0  Charging at end of hour  92.17164418303832
# EV1  Charging...  86.55999780133908 , Location:  Home
# EV1  Charging at end of hour  96.03199780133907
# EV2  Charging...  87.33937807238831 , Location:  Home
# EV2  Charging at end of hour  96.81137807238832
# EV3  Charging...  83.399486103855 , Location:  Work2
# EV3  Charging at end of hour  92.87148610385499
# EV6  Charging...  84.37865169968812 , Location:  Home
# EV6  Charging at end of hour  93.85065169968814
# EV7  Charging...  85.70322598928031 , Location:  Work2
# EV7  Charging at end of hour  95.1752259892803
# EV8  Charging...  87.46513257969752 , Location:  Home
# EV8  Charging at end of hour  96.93713257969753
# EV9  Charging...  82.63751375677366 , Location:  Work1
# EV9  Charging at end of hour  92.10951375677368
#
# Total Generation:  0.29584277802630127
# Total Demand:  84.36198238592445
# Initial deficit:  84.06613960789815
# Demand w/ no EVs:  27.52998238592445
# New deficit:  27.234139607898147
# Running PSO...
# Output:  [3.31053498 3.61748638 3.65719367 3.35025059 3.28244615 3.23285441
#  3.42842495 3.35496494]
# Updated Gen:  27.52999884769301
# Updated Demand:  -1.6461768563402757e-05
#
# Hour:  9
# EV0  Charging...  87.75759754838445 , Location:  Home
# EV0  Charging at end of hour  97.22959754838445
# EV1  Charging...  89.60497338977706 , Location:  Work2
# EV1  Charging at end of hour  99.07697338977705
# EV2  Charging...  91.93511985049288 , Location:  Home
# EV2  Charging at end of hour  101.40711985049289
# EV3  Charging...  88.40448531409102 , Location:  Work2
# EV3  Charging at end of hour  97.87648531409103
# EV6  Charging...  89.27941843350516 , Location:  Home
# EV6  Charging at end of hour  98.75141843350515
# EV7  Charging...  90.70193940195811 , Location:  Work2
# EV7  Charging at end of hour  100.17393940195811
# EV9  Charging...  92.10951375677368 , Location:  Work1
# EV9  Charging at end of hour  101.58151375677366
#
# Total Generation:  2.685205546116277
# Total Demand:  71.01606724202614
# Initial deficit:  68.33086169590986
# Demand w/ no EVs:  21.288067242026138
# New deficit:  18.602861695909862
# Running PSO...
# Output:  [2.58241305 2.51183129 2.79653016 2.63896927 2.78181605 2.59588546
#  2.6954162 ]
# Updated Gen:  21.28806703015605
# Updated Demand:  2.1187008769629756e-07
#
# Hour:  10
# EV1  Charging...  95.72786500502859 , Location:  Work2
# EV1  Charging at end of hour  105.19986500502858
# EV2  Charging...  94.78365525345635 , Location:  Work2
# EV2  Charging at end of hour  104.25565525345635
# EV3  Charging...  94.35785961457685 , Location:  Work2
# EV3  Charging at end of hour  103.82985961457685
# EV7  Charging...  100.17393940195811 , Location:  Work2
# EV7  Charging at end of hour  109.64593940195813
# EV9  Charging...  101.58151375677366 , Location:  Work1
# EV9  Charging at end of hour  111.05351375677365
#
# Total Generation:  4.57276935163073
# Total Demand:  55.591743976225054
# Initial deficit:  51.01897462459432
# Demand w/ no EVs:  20.07174397622505
# New deficit:  15.498974624594322
# Running PSO...
# Output:  [3.03756962 3.02322683 3.02930759 3.15427336 3.2545927 ]
# Updated Gen:  20.071739457327656
# Updated Demand:  4.518897394945043e-06
#
# Hour:  11
# EV1  Charging...  101.16889589634341 , Location:  Work2
# EV1  Charging at end of hour  110.64089589634341
# EV2  Charging...  100.21657846026419 , Location:  Work2
# EV2  Charging at end of hour  109.68857846026418
# EV3  Charging...  99.62416180447279 , Location:  Work2
# EV3  Charging at end of hour  109.09616180447279
# EV4  Charging...  73.8851673184728 , Location:  Work1
# EV4  Charging at end of hour  83.3571673184728
# EV7  Charging...  109.64593940195813 , Location:  Work2
# EV7  Charging at end of hour  119.11793940195811
# EV8  Charging...  95.11237274496632 , Location:  Work2
# EV8  Charging at end of hour  104.58437274496633
# EV9  Charging...  111.05351375677365 , Location:  Work1
# EV9  Charging at end of hour  120.52551375677368
#
# Total Generation:  5.884392730085999
# Total Demand:  69.01794558049474
# Initial deficit:  63.13355285040874
# Demand w/ no EVs:  19.289945580494738
# New deficit:  13.40555285040874
# Running PSO...
# Output:  [1.65584513 1.79945297 2.17692156 1.47693546 2.24793166 1.99235565
#  2.05609057]
# Updated Gen:  19.289925734225775
# Updated Demand:  1.984626896245345e-05
#
# Hour:  12
# EV1  Charging...  108.24162527087442 , Location:  Work2
# EV1  Charging at end of hour  117.71362527087443
# EV2  Charging...  106.78601637515904 , Location:  Work2
# EV2  Charging at end of hour  116.25801637515904
# EV3  Charging...  107.12691452491474 , Location:  Work2
# EV3  Charging at end of hour  116.59891452491473
# EV4  Charging...  80.35992510550895 , Location:  Work1
# EV4  Charging at end of hour  89.83192510550896
# EV5  Charging...  73.44708859705551 , Location:  Home
# EV5  Charging at end of hour  82.9190885970555
# EV6  Charging...  89.01635450763614 , Location:  Work1
# EV6  Charging at end of hour  98.48835450763613
# EV7  Charging...  119.11793940195811 , Location:  Work2
# EV7  Charging at end of hour  128.5899394019581
# EV8  Charging...  104.58437274496633 , Location:  Work2
# EV8  Charging at end of hour  114.05637274496631
#
# Total Generation:  6.467469063240203
# Total Demand:  77.34570613050339
# Initial deficit:  70.87823706726319
# Demand w/ no EVs:  20.513706130503387
# New deficit:  14.046237067263185
# Running PSO...
# Output:  [1.85152808 1.5140551  2.10038929 1.24326715 1.22831755 1.74029929
#  2.43369655 1.93464951]
# Updated Gen:  20.513671587459836
# Updated Demand:  3.454304355088311e-05
#
# Hour:  13
# EV0  Charging...  82.65262707088219 , Location:  Work2
# EV0  Charging at end of hour  92.12462707088218
# EV1  Charging...  115.69488513463962 , Location:  Work2
# EV1  Charging at end of hour  125.16688513463963
# EV2  Charging...  113.45749731958696 , Location:  Work2
# EV2  Charging at end of hour  122.92949731958696
# EV4  Charging...  88.19416837479258 , Location:  Work1
# EV4  Charging at end of hour  97.66616837479259
# EV5  Charging...  80.59868955035671 , Location:  Home
# EV5  Charging at end of hour  90.0706895503567
# EV6  Charging...  95.24342576764617 , Location:  Work1
# EV6  Charging at end of hour  104.71542576764618
# EV8  Charging...  114.05637274496631 , Location:  Work2
# EV8  Charging at end of hour  123.52837274496633
#
# Total Generation:  6.6675315894236675
# Total Demand:  69.50246024032246
# Initial deficit:  62.834928650898796
# Demand w/ no EVs:  19.774460240322462
# New deficit:  13.106928650898794
# Running PSO...
# Output:  [2.16231355 1.80015867 2.14003493 1.82028575 1.34061623 1.89599845
#  1.94754866]
# Updated Gen:  19.77448782267046
# Updated Demand:  -2.7582347996712997e-05
#
# Hour:  14
# EV0  Charging...  89.24154234049644 , Location:  Work2
# EV0  Charging at end of hour  98.71354234049645
# EV2  Charging...  120.07611740928374 , Location:  Work2
# EV2  Charging at end of hour  129.54811740928375
# EV4  Charging...  95.87868007467425 , Location:  Work1
# EV4  Charging at end of hour  105.35068007467426
# EV5  Charging...  87.5426916215551 , Location:  Home
# EV5  Charging at end of hour  97.01469162155509
# EV6  Charging...  102.11869421780561 , Location:  Work1
# EV6  Charging at end of hour  111.5906942178056
# EV8  Charging...  123.52837274496633 , Location:  Work2
# EV8  Charging at end of hour  133.0003727449663
#
# Total Generation:  5.5161217435016034
# Total Demand:  62.88212093792483
# Initial deficit:  57.365999194423225
# Demand w/ no EVs:  20.25812093792483
# New deficit:  14.741999194423226
# Running PSO...
# Output:  [2.10617939 2.95086123 2.17958678 2.07062932 2.42681081 3.0079323 ]
# Updated Gen:  20.258121574072995
# Updated Demand:  -6.361481652561451e-07
#
# Hour:  15
# EV0  Charging...  95.90530315337983 , Location:  Work2
# EV0  Charging at end of hour  105.37730315337983
# EV3  Charging...  108.80693789594906 , Location:  Work1
# EV3  Charging at end of hour  118.27893789594907
# EV4  Charging...  102.1149323336938 , Location:  Work1
# EV4  Charging at end of hour  111.58693233369381
# EV5  Charging...  93.00411522750504 , Location:  Home
# EV5  Charging at end of hour  102.47611522750503
# EV6  Charging...  111.5906942178056 , Location:  Work1
# EV6  Charging at end of hour  121.0626942178056
# EV8  Charging...  133.0003727449663 , Location:  Work2
# EV8  Charging at end of hour  142.47237274496632
# EV9  Charging...  118.85497363095192 , Location:  Work2
# EV9  Charging at end of hour  128.32697363095193
#
# Total Generation:  3.750212020913834
# Total Demand:  70.52607715536041
# Initial deficit:  66.77586513444658
# Demand w/ no EVs:  20.79807715536041
# New deficit:  17.047865134446575
# Running PSO...
# Output:  [2.20074922 2.6561053  2.462866   2.02638719 2.28718702 2.69853628
#  2.71606555]
# Updated Gen:  20.798108573663384
# Updated Demand:  -3.141830297437309e-05
#
# Hour:  16
# EV0  Charging...  102.44297086319334 , Location:  Work2
# EV0  Charging at end of hour  111.91497086319333
# EV1  Charging...  112.93359096171226 , Location:  Home
# EV1  Charging at end of hour  122.40559096171224
# EV3  Charging...  115.577088313896 , Location:  Work1
# EV3  Charging at end of hour  125.04908831389598
# EV4  Charging...  107.77800345520387 , Location:  Work2
# EV4  Charging at end of hour  117.25000345520387
# EV5  Charging...  98.8780668513365 , Location:  Home
# EV5  Charging at end of hour  108.3500668513365
# EV6  Charging...  117.44127348524643 , Location:  Work1
# EV6  Charging at end of hour  126.91327348524644
# EV9  Charging...  128.32697363095193 , Location:  Work2
# EV9  Charging at end of hour  137.79897363095193
#
# Total Generation:  0.31486897150188764
# Total Demand:  77.99696730199621
# Initial deficit:  77.68209833049431
# Demand w/ no EVs:  28.268967301996206
# New deficit:  27.95409833049432
# Running PSO...
# Output:  [3.52922114 4.05548591 4.07964717 3.89192832 3.62466857 3.90356401
#  4.86960024]
# Updated Gen:  28.26898434786898
# Updated Demand:  -1.7045872773735482e-05
#
# Hour:  17
# EV0  Charging...  107.2093426711217 , Location:  Work2
# EV0  Charging at end of hour  116.68134267112171
# EV2  Charging...  116.29317429448795 , Location:  Work1
# EV2  Charging at end of hour  125.76517429448795
# EV3  Charging...  119.85985055167907 , Location:  Work1
# EV3  Charging at end of hour  129.33185055167905
# EV4  Charging...  112.41711202228564 , Location:  Work2
# EV4  Charging at end of hour  121.88911202228564
# EV5  Charging...  103.14531483415448 , Location:  Home
# EV5  Charging at end of hour  112.61731483415447
# EV6  Charging...  120.33647136530574 , Location:  Work2
# EV6  Charging at end of hour  129.80847136530576
# EV9  Charging...  137.79897363095193 , Location:  Work2
# EV9  Charging at end of hour  147.27097363095191
#
# Total Generation:  0.0
# Total Demand:  88.39691444532875
# Initial deficit:  88.39691444532875
# Demand w/ no EVs:  38.668914445328745
# New deficit:  38.668914445328745
# Running PSO...
# Output:  [5.03889911 5.5384336  5.56384825 5.16174287 5.06736457 5.83010339
#  6.46852267]
# Updated Gen:  38.66891446838068
# Updated Demand:  -2.305193191887156e-08
#
# Hour:  18
# EV0  Charging...  109.77388908224341 , Location:  Work1
# EV0  Charging at end of hour  119.24588908224341
# EV2  Charging...  118.3467099613174 , Location:  Work1
# EV2  Charging at end of hour  127.8187099613174
# EV3  Charging...  122.44952672090707 , Location:  Work1
# EV3  Charging at end of hour  131.92152672090708
# EV4  Charging...  115.13262592273136 , Location:  Work2
# EV4  Charging at end of hour  124.60462592273139
# EV5  Charging...  104.8438436426494 , Location:  Home
# EV5  Charging at end of hour  114.3158436426494
# EV6  Charging...  121.18377447481083 , Location:  Work2
# EV6  Charging at end of hour  130.6557744748108
# EV7  Charging...  119.8309983935977 , Location:  Home
# EV7  Charging at end of hour  129.3029983935977
# EV9  Charging...  147.27097363095191 , Location:  Work2
# EV9  Charging at end of hour  156.74297363095192
#
# Total Generation:  0.07510204787945837
# Total Demand:  100.19528627052155
# Initial deficit:  100.1201842226421
# Demand w/ no EVs:  43.36328627052155
# New deficit:  43.28818422264209
# Running PSO...
# Output:  [5.33317709 5.55815909 5.50049033 5.40841244 5.12127033 4.9924162
#  5.04773202 6.32652635]
# Updated Gen:  43.36328590751046
# Updated Demand:  3.630110896324368e-07
#
# Hour:  19
# EV0  Charging...  112.13498629453464 , Location:  Work1
# EV0  Charging at end of hour  121.60698629453464
# EV1  Charging...  98.61023907872894 , Location:  Work1
# EV1  Charging at end of hour  108.08223907872893
# EV2  Charging...  120.48472285832416 , Location:  Work1
# EV2  Charging at end of hour  129.95672285832416
# EV3  Charging...  124.71031013248843 , Location:  Work1
# EV3  Charging at end of hour  134.18231013248842
# EV4  Charging...  117.77626547772175 , Location:  Work2
# EV4  Charging at end of hour  127.24826547772177
# EV5  Charging...  107.65928870611945 , Location:  Home
# EV5  Charging at end of hour  117.13128870611943
# EV6  Charging...  123.92546510946812 , Location:  Work2
# EV6  Charging at end of hour  133.39746510946813
# EV7  Charging...  120.86762992886091 , Location:  Home
# EV7  Charging at end of hour  130.33962992886092
# EV8  Charging...  140.46332321937754 , Location:  Home
# EV8  Charging at end of hour  149.93532321937752
# EV9  Charging...  156.74297363095192 , Location:  Work2
# EV9  Charging at end of hour  166.21497363095193
#
# Total Generation:  0.30107571312366904
# Total Demand:  112.64449969182104
# Initial deficit:  112.34342397869737
# Demand w/ no EVs:  41.60449969182103
# New deficit:  41.30342397869737
# Running PSO...
# Output:  [3.65774167 3.37684431 4.04740038 4.1425989  4.10458532 3.86265324
#  4.15604165 4.18427727 4.59427309 5.177011  ]
# Updated Gen:  41.60450253310219
# Updated Demand:  -2.841281158794118e-06
#
# Hour:  20
# EV0  Charging...  116.72999740552274 , Location:  Work1
# EV0  Charging at end of hour  126.20199740552273
# EV1  Charging...  103.57978000213883 , Location:  Work1
# EV1  Charging at end of hour  113.05178000213884
# EV2  Charging...  124.56018902021397 , Location:  Work1
# EV2  Charging at end of hour  134.03218902021396
# EV4  Charging...  121.7754850478045 , Location:  Work2
# EV4  Charging at end of hour  131.24748504780447
# EV5  Charging...  111.98108438613659 , Location:  Home
# EV5  Charging at end of hour  121.45308438613658
# EV6  Charging...  127.85607624756992 , Location:  Work2
# EV6  Charging at end of hour  137.3280762475699
# EV7  Charging...  124.7605935654288 , Location:  Home
# EV7  Charging at end of hour  134.2325935654288
# EV8  Charging...  143.80962577252333 , Location:  Home
# EV8  Charging at end of hour  153.28162577252334
# EV9  Charging...  155.02027044666175 , Location:  Home
# EV9  Charging at end of hour  164.49227044666173
#
# Total Generation:  0.14431004923391103
# Total Demand:  102.22235595832652
# Initial deficit:  102.07804590909261
# Demand w/ no EVs:  38.28635595832652
# New deficit:  38.14204590909261
# Running PSO...
# Output:  [4.10107112 3.68222191 4.25397556 4.01044613 3.73652733 4.19772728
#  4.25357544 4.57076922 5.3357148 ]
# Updated Gen:  38.28633885635953
# Updated Demand:  1.7101966989230277e-05
#
# Hour:  21
# EV0  Charging...  120.73390257394021 , Location:  Work1
# EV0  Charging at end of hour  130.2059025739402
# EV1  Charging...  108.14215078977408 , Location:  Work1
# EV1  Charging at end of hour  117.61415078977409
# EV2  Charging...  128.3602216010719 , Location:  Work1
# EV2  Charging at end of hour  137.83222160107192
# EV4  Charging...  124.44943509302516 , Location:  Home
# EV4  Charging at end of hour  133.92143509302517
# EV5  Charging...  115.85611467453705 , Location:  Home
# EV5  Charging at end of hour  125.32811467453703
# EV6  Charging...  131.656642323144 , Location:  Work2
# EV6  Charging at end of hour  141.12864232314402
# EV7  Charging...  128.1382346073902 , Location:  Home
# EV7  Charging at end of hour  137.61023460739017
# EV8  Charging...  146.16733936858864 , Location:  Home
# EV8  Charging at end of hour  155.63933936858865
# EV9  Charging...  164.49227044666173 , Location:  Home
# EV9  Charging at end of hour  173.96427044666177
#
# Total Generation:  0.572481579853587
# Total Demand:  97.02938967300022
# Initial deficit:  96.45690809314664
# Demand w/ no EVs:  33.093389673000225
# New deficit:  32.52090809314664
# Running PSO...
# Output:  [3.42123755 2.86412862 2.88363616 3.43655672 3.60878335 3.81843476
#  3.74087325 4.02093681 4.7263155 ]
# Updated Gen:  33.09338430191839
# Updated Demand:  5.3710818335162e-06
#
# Hour:  22
# EV0  Charging...  125.6442525119514 , Location:  Work1
# EV0  Charging at end of hour  135.11625251195142
# EV1  Charging...  113.79531262963725 , Location:  Work1
# EV1  Charging at end of hour  123.26731262963726
# EV2  Charging...  129.6953515293248 , Location:  Home
# EV2  Charging at end of hour  139.16735152932478
# EV3  Charging...  113.32231507371888 , Location:  Home
# EV3  Charging at end of hour  122.79431507371889
# EV4  Charging...  129.10972396547734 , Location:  Home
# EV4  Charging at end of hour  138.58172396547735
# EV5  Charging...  120.23686832470682 , Location:  Home
# EV5  Charging at end of hour  129.7088683247068
# EV7  Charging...  132.2489855220585 , Location:  Home
# EV7  Charging at end of hour  141.72098552205853
# EV8  Charging...  149.3375853688939 , Location:  Home
# EV8  Charging at end of hour  158.80958536889392
# EV9  Charging...  173.96427044666177 , Location:  Home
# EV9  Charging at end of hour  183.4362704466618
#
# Total Generation:  0.21355902069210228
# Total Demand:  90.01282261351301
# Initial deficit:  89.7992635928209
# Demand w/ no EVs:  26.07682261351301
# New deficit:  25.863263592820907
# Running PSO...
# Output:  [3.04173442 2.75089691 3.17528768 2.07340315 2.90362311 2.99356507
#  2.4962207  2.90583654 3.52268615]
# Updated Gen:  26.07681274885442
# Updated Demand:  9.864658590430508e-06
#
# Hour:  23
# EV0  Charging...  129.53059357177793 , Location:  Home
# EV0  Charging at end of hour  139.0025935717779
# EV1  Charging...  119.5994500853718 , Location:  Work1
# EV1  Charging at end of hour  129.07145008537182
# EV2  Charging...  134.93363462273865 , Location:  Home
# EV2  Charging at end of hour  144.40563462273863
# EV3  Charging...  120.02977753747982 , Location:  Home
# EV3  Charging at end of hour  129.5017775374798
# EV4  Charging...  134.71022648719995 , Location:  Home
# EV4  Charging at end of hour  144.18222648719993
# EV5  Charging...  125.71744823276254 , Location:  Home
# EV5  Charging at end of hour  135.18944823276254
# EV7  Charging...  137.84653680843198 , Location:  Home
# EV7  Charging at end of hour  147.31853680843196
# EV8  Charging...  154.1126705002572 , Location:  Home
# EV8  Charging at end of hour  163.5846705002572
# EV9  Charging...  183.4362704466618 , Location:  Home
# EV9  Charging at end of hour  192.90827044666182
#
# Total Generation:  0.03221689884891364
# Total Demand:  82.4218005936045
# Initial deficit:  82.38958369475559
# Demand w/ no EVs:  18.485800593604502
# New deficit:  18.453583694755586
# Running PSO...
# Output:  [1.56076564 2.65256182 1.53209856 1.7450466  2.11601915 1.50135799
#  1.74475093 4.01451353 1.58647062]
# Updated Gen:  18.4858017231959
# Updated Demand:  -1.129591399973151e-06

# %%
G.nodes['647313']
# Out:
# {'y': '55.9352985',
#  'x': '-3.3069659',
#  'street_count': '3',
#  'type': 'home',
#  'agent': [<__main__.EVAgent at 0x1a3450f8bb0>,
#   <__main__.EVAgent at 0x1a3450f8c10>,
#   <__main__.EVAgent at 0x1a34513d0a0>]}

# %%
G.nodes['13796018']
# Out:
# {'y': '55.9415554',
#  'x': '-3.1782155',
#  'street_count': '3',
#  'type': 'work',
#  'agent': []}

# %%
def obj_function(x, demand, charges):
    perc = x/charges*100
    value = abs(demand-np.sum(x,axis=1)) + np.var(perc, axis=1)
    return value

# %%
options = {'c1': 0.3, 'c2': 0.5, 'w':0.7}

# %%
bounds = (np.array([0,0,0]),np.array([7,7,7]))

# %%
optimizer = ps.single.GlobalBestPSO(n_particles=50, dimensions=3, options=options, bounds=bounds)

# %%
cost, pos = optimizer.optimize(obj_function, iters=10, demand=12, charges=np.array([70, 10, 70]))
# Out:
# 2022-07-27 17:12:24,843 - pyswarms.single.global_best - INFO - Optimize for 10 iters with {'c1': 0.3, 'c2': 0.5, 'w': 0.7}
# pyswarms.single.global_best: 100%|██████████|10/10, best_cost=0.354
# 2022-07-27 17:12:24,859 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.353948356273515, best pos: [5.30897637 0.71343938 5.93758937]

# %%
pos
# Out:
# array([5.30897637, 0.71343938, 5.93758937])

# %%
pos.sum()
# Out:
# 11.960005125693582

# %%
np.full(10,7)
# Out:
# array([7, 7, 7, 7, 7, 7, 7, 7, 7, 7])
